# %%
import pandas as pd

# %%
# load pairwise dataset
fn = '/fs/nexus-scratch/rhaworth/plasmid/pairs.txt'
data = pd.read_csv(fn, sep='\t')
data
# Out:
#                                        Assembly_ID                Taxonomy  \
# 0      GCA_023703895.1_ASM2370389v1_genomic.fna.gz   KLEBSIELLA PNEUMONIAE
# 1      GCF_024662395.1_ASM2466239v1_genomic.fna.gz     BURKHOLDERIA GLUMAE
# 2      GCF_024662395.1_ASM2466239v1_genomic.fna.gz     BURKHOLDERIA GLUMAE
# 3      GCF_024662395.1_ASM2466239v1_genomic.fna.gz     BURKHOLDERIA GLUMAE
# 4      GCA_012971805.2_ASM1297180v2_genomic.fna.gz      RHODOCOCCUS OPACUS
# ...                                            ...                     ...
# 50871   GCF_003595385.1_ASM359538v1_genomic.fna.gz   STAPHYLOCOCCUS AUREUS
# 50872   GCF_003595385.1_ASM359538v1_genomic.fna.gz   STAPHYLOCOCCUS AUREUS
# 50873  GCF_039640675.1_ASM3964067v1_genomic.fna.gz  STAPHYLOCOCCUS CAPITIS
# 50874  GCF_039640675.1_ASM3964067v1_genomic.fna.gz  STAPHYLOCOCCUS CAPITIS
# 50875  GCF_039640675.1_ASM3964067v1_genomic.fna.gz  STAPHYLOCOCCUS CAPITIS
#
#                      Chromosome_ID     Plasmid_ID  Chr_len  Plasmid_len  \
# 0                       CP077812.1     CP077813.1  5167508        54288
# 1      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100133.1  6558951       189346
# 2      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100134.1  6558951       128913
# 3      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100135.1  6558951       104740
# 4            CP128998.1,CP128999.1     CP129000.1  9807637        54121
# ...                            ...            ...      ...          ...
# 50871                NZ_CP014365.1  NZ_CP014366.1  2904958         3125
# 50872                NZ_CP014365.1  NZ_CP014367.1  2904958        27068
# 50873                NZ_CP098816.1  NZ_CP098817.1  2443214        44138
# 50874                NZ_CP098816.1  NZ_CP098818.1  2443214        39504
# 50875                NZ_CP098816.1  NZ_CP098819.1  2443214        22579
#
#          Chr_GC  Plasmid_GC
# 0      0.575169    0.527888
# 1      0.683257    0.638836
# 2      0.683257    0.614430
# 3      0.683257    0.636500
# 4      0.669073    0.667671
# ...         ...         ...
# 50871  0.327958    0.287360
# 50872  0.327958    0.305231
# 50873  0.330543    0.300580
# 50874  0.330543    0.289464
# 50875  0.330543    0.289473
#
# [50876 rows x 8 columns]

# %%
# load 4mers
fn = '/fs/nexus-projects/plasmids/plasmid_host_range_2024_summer_interns/expanded_dataset/4mer_table.txt'
data_4mers = pd.read_csv(fn, sep='\t')
data_4mers
# Out:
#                                                 Assembly    Seq_type  \
# 0                       GCA_000005825.2_ASM582v2_genomic  chromosome
# 1                       GCA_000005845.2_ASM584v2_genomic  chromosome
# 2                       GCA_000006605.1_ASM660v1_genomic  chromosome
# 3                       GCA_000006625.1_ASM662v1_genomic  chromosome
# 4                       GCA_000006645.1_ASM664v1_genomic  chromosome
# ...                                                  ...         ...
# 91820  GCF_964199155.1_Zagreb009_hybrid_assembly.fa.g...     plasmid
# 91821                   GCF_964205035.1_18MA0850_genomic     plasmid
# 91822                   GCF_964205035.1_18MA0850_genomic     plasmid
# 91823                   GCF_964205045.1_18MA0854_genomic     plasmid
# 91824                   GCF_964205045.1_18MA0854_genomic     plasmid
#
#                                   SeqID     AAAA     AAAC     AAAG     AAAT  \
# 0      GCA_000005825.2_ASM582v2_genomic  90881.0  42325.0  60895.0  68917.0
# 1      GCA_000005845.2_ASM584v2_genomic  70767.0  50477.0  45989.0  51593.0
# 2      GCA_000006605.1_ASM660v1_genomic  10309.0  11534.0  12081.0   6826.0
# 3      GCA_000006625.1_ASM662v1_genomic  43692.0  13073.0  11309.0  33335.0
# 4      GCA_000006645.1_ASM664v1_genomic  75622.0  47896.0  43794.0  60630.0
# ...                                 ...      ...      ...      ...      ...
# 91820                     NZ_OZ111549.1     79.0     30.0     32.0     24.0
# 91821                     NZ_OZ123584.1    131.0    191.0    158.0    106.0
# 91822                     NZ_OZ123585.1     79.0     86.0     75.0     57.0
# 91823                     NZ_OZ123587.1    119.0    173.0    133.0    100.0
# 91824                     NZ_OZ123588.1     79.0     86.0     75.0     57.0
#
#           AACA     AACC     AACG  ...     TAAA     TACA     TAGA     TATA  \
# 0      43978.0  24963.0  27889.0  ...  67461.0  33931.0  31822.0  17586.0
# 1      43674.0  40859.0  48632.0  ...  44665.0  21282.0  11307.0   9081.0
# 2      13481.0  18306.0  17508.0  ...   5623.0   7450.0   7014.0   1039.0
# 3      13659.0   4502.0   3782.0  ...  33630.0   5964.0   5654.0   5887.0
# 4      46161.0  43690.0  39865.0  ...  55190.0  23874.0  17241.0  13213.0
# ...        ...      ...      ...  ...      ...      ...      ...      ...
# 91820     15.0     13.0     31.0  ...     23.0     18.0     16.0      5.0
# 91821    243.0    370.0    404.0  ...     36.0    123.0     83.0      7.0
# 91822     88.0    160.0    143.0  ...     24.0     55.0     30.0      5.0
# 91823    224.0    315.0    356.0  ...     28.0    110.0     75.0      7.0
# 91824     88.0    160.0    143.0  ...     24.0     55.0     30.0      5.0
#
#           TCAA     TCCA     TCGA     TGAA     TGCA     TTAA
# 0      52989.0  30674.0   9695.0  59606.0  17647.0  31864.0
# 1      38771.0  33770.0  15462.0  51762.0  19768.0  21209.0
# 2      12658.0  24371.0  12682.0  15320.0   9582.0   2712.0
# 3      13983.0   3824.0    912.0  12956.0   2571.0  16985.0
# 4      48290.0  32235.0  11718.0  51982.0  18633.0  23183.0
# ...        ...      ...      ...      ...      ...      ...
# 91820     33.0     20.0      6.0     29.0      6.0     10.0
# 91821    267.0    294.0    364.0    213.0    174.0     15.0
# 91822    108.0    110.0    144.0     86.0     74.0     12.0
# 91823    233.0    261.0    326.0    191.0    157.0     13.0
# 91824    108.0    110.0    144.0     86.0     74.0     12.0
#
# [91825 rows x 139 columns]

# %%
# split 4mers into chromosomes/plasmids
c_idx = data_4mers.index[data_4mers['Seq_type'] == 'chromosome']
c_4mers = data_4mers.iloc[c_idx]
p_4mers = data_4mers.iloc[~c_idx]
print(c_4mers['Seq_type'].unique())
print(p_4mers['Seq_type'].unique())
# Out:
# ['chromosome']
# ['plasmid']

# %%
# get chromosome 4mers in order of pairwise dataset
labels = data['Assembly_ID'].str[:-7] # strip filename
_c4 = c_4mers.set_index('SeqID')
# a few labels are not found in c_4mers, so just drop them i guess
labels_to_keep = labels.isin(c_4mers['SeqID'])
labels = labels[labels_to_keep]

c4m = _c4.loc[labels]
c4m
# Out:
#                                                                   Assembly  \
# SeqID
# GCA_023703895.1_ASM2370389v1_genomic  GCA_023703895.1_ASM2370389v1_genomic
# GCF_024662395.1_ASM2466239v1_genomic  GCF_024662395.1_ASM2466239v1_genomic
# GCF_024662395.1_ASM2466239v1_genomic  GCF_024662395.1_ASM2466239v1_genomic
# GCF_024662395.1_ASM2466239v1_genomic  GCF_024662395.1_ASM2466239v1_genomic
# GCA_012971805.2_ASM1297180v2_genomic  GCA_012971805.2_ASM1297180v2_genomic
# ...                                                                    ...
# GCF_003595385.1_ASM359538v1_genomic    GCF_003595385.1_ASM359538v1_genomic
# GCF_003595385.1_ASM359538v1_genomic    GCF_003595385.1_ASM359538v1_genomic
# GCF_039640675.1_ASM3964067v1_genomic  GCF_039640675.1_ASM3964067v1_genomic
# GCF_039640675.1_ASM3964067v1_genomic  GCF_039640675.1_ASM3964067v1_genomic
# GCF_039640675.1_ASM3964067v1_genomic  GCF_039640675.1_ASM3964067v1_genomic
#
#                                         Seq_type     AAAA     AAAC     AAAG  \
# SeqID
# GCA_023703895.1_ASM2370389v1_genomic  chromosome  56811.0  39993.0  42497.0
# GCF_024662395.1_ASM2466239v1_genomic  chromosome  15936.0  17157.0  13250.0
# GCF_024662395.1_ASM2466239v1_genomic  chromosome  15936.0  17157.0  13250.0
# GCF_024662395.1_ASM2466239v1_genomic  chromosome  15936.0  17157.0  13250.0
# GCA_012971805.2_ASM1297180v2_genomic  chromosome   7568.0  20515.0  13250.0
# ...                                          ...      ...      ...      ...
# GCF_003595385.1_ASM359538v1_genomic   chromosome  88416.0  36930.0  44999.0
# GCF_003595385.1_ASM359538v1_genomic   chromosome  88416.0  36930.0  44999.0
# GCF_039640675.1_ASM3964067v1_genomic  chromosome  67177.0  30928.0  39504.0
# GCF_039640675.1_ASM3964067v1_genomic  chromosome  67177.0  30928.0  39504.0
# GCF_039640675.1_ASM3964067v1_genomic  chromosome  67177.0  30928.0  39504.0
#
#                                          AAAT     AACA     AACC     AACG  \
# SeqID
# GCA_023703895.1_ASM2370389v1_genomic  37034.0  33033.0  36321.0  41485.0
# GCF_024662395.1_ASM2466239v1_genomic  16569.0  26340.0  26860.0  47610.0
# GCF_024662395.1_ASM2466239v1_genomic  16569.0  26340.0  26860.0  47610.0
# GCF_024662395.1_ASM2466239v1_genomic  16569.0  26340.0  26860.0  47610.0
# GCA_012971805.2_ASM1297180v2_genomic  12206.0  40854.0  56397.0  69700.0
# ...                                       ...      ...      ...      ...
# GCF_003595385.1_ASM359538v1_genomic   85338.0  44229.0  16772.0  19766.0
# GCF_003595385.1_ASM359538v1_genomic   85338.0  44229.0  16772.0  19766.0
# GCF_039640675.1_ASM3964067v1_genomic  66957.0  32348.0  14958.0  16162.0
# GCF_039640675.1_ASM3964067v1_genomic  66957.0  32348.0  14958.0  16162.0
# GCF_039640675.1_ASM3964067v1_genomic  66957.0  32348.0  14958.0  16162.0
#
#                                          AACT  ...     TAAA     TACA     TAGA  \
# SeqID                                          ...
# GCA_023703895.1_ASM2370389v1_genomic  22786.0  ...  34999.0  16208.0  11026.0
# GCF_024662395.1_ASM2466239v1_genomic  19874.0  ...   4780.0  12342.0  10419.0
# GCF_024662395.1_ASM2466239v1_genomic  19874.0  ...   4780.0  12342.0  10419.0
# GCF_024662395.1_ASM2466239v1_genomic  19874.0  ...   4780.0  12342.0  10419.0
# GCA_012971805.2_ASM1297180v2_genomic  41261.0  ...   2512.0  20100.0  12931.0
# ...                                       ...  ...      ...      ...      ...
# GCF_003595385.1_ASM359538v1_genomic   30342.0  ...  80969.0  31753.0  25172.0
# GCF_003595385.1_ASM359538v1_genomic   30342.0  ...  80969.0  31753.0  25172.0
# GCF_039640675.1_ASM3964067v1_genomic  27851.0  ...  69879.0  24925.0  24263.0
# GCF_039640675.1_ASM3964067v1_genomic  27851.0  ...  69879.0  24925.0  24263.0
# GCF_039640675.1_ASM3964067v1_genomic  27851.0  ...  69879.0  24925.0  24263.0
#
#                                          TATA     TCAA     TCCA      TCGA  \
# SeqID
# GCA_023703895.1_ASM2370389v1_genomic   8255.0  32990.0  37421.0   20935.0
# GCF_024662395.1_ASM2466239v1_genomic   2043.0  25286.0  32144.0   64817.0
# GCF_024662395.1_ASM2466239v1_genomic   2043.0  25286.0  32144.0   64817.0
# GCF_024662395.1_ASM2466239v1_genomic   2043.0  25286.0  32144.0   64817.0
# GCA_012971805.2_ASM1297180v2_genomic   1242.0  31294.0  62458.0  102586.0
# ...                                       ...      ...      ...       ...
# GCF_003595385.1_ASM359538v1_genomic   23405.0  46090.0  18894.0    7004.0
# GCF_003595385.1_ASM359538v1_genomic   23405.0  46090.0  18894.0    7004.0
# GCF_039640675.1_ASM3964067v1_genomic  19210.0  38717.0  16109.0    5298.0
# GCF_039640675.1_ASM3964067v1_genomic  19210.0  38717.0  16109.0    5298.0
# GCF_039640675.1_ASM3964067v1_genomic  19210.0  38717.0  16109.0    5298.0
#
#                                          TGAA     TGCA     TTAA
# SeqID
# GCA_023703895.1_ASM2370389v1_genomic  42555.0  19699.0  15680.0
# GCF_024662395.1_ASM2466239v1_genomic  34361.0  23089.0   1488.0
# GCF_024662395.1_ASM2466239v1_genomic  34361.0  23089.0   1488.0
# GCF_024662395.1_ASM2466239v1_genomic  34361.0  23089.0   1488.0
# GCA_012971805.2_ASM1297180v2_genomic  40596.0  30106.0    899.0
# ...                                       ...      ...      ...
# GCF_003595385.1_ASM359538v1_genomic   48760.0  14197.0  37970.0
# GCF_003595385.1_ASM359538v1_genomic   48760.0  14197.0  37970.0
# GCF_039640675.1_ASM3964067v1_genomic  42747.0   9307.0  32466.0
# GCF_039640675.1_ASM3964067v1_genomic  42747.0   9307.0  32466.0
# GCF_039640675.1_ASM3964067v1_genomic  42747.0   9307.0  32466.0
#
# [50851 rows x 138 columns]

# %%
labels = data['Plasmid_ID']
# drop labels
labels = labels[labels_to_keep]
_p4 = p_4mers.set_index('SeqID')

labels_to_keep_p = labels.isin(p_4mers['SeqID'])
labels = labels[labels_to_keep_p]

p4m = _p4.loc[labels]
p4m
# Out:
#                                            Assembly Seq_type    AAAA    AAAC  \
# SeqID
# CP077813.1     GCA_023703895.1_ASM2370389v1_genomic  plasmid   824.0   547.0
# NZ_CP100133.1  GCF_024662395.1_ASM2466239v1_genomic  plasmid   684.0   763.0
# NZ_CP100134.1  GCF_024662395.1_ASM2466239v1_genomic  plasmid   581.0   674.0
# NZ_CP100135.1  GCF_024662395.1_ASM2466239v1_genomic  plasmid   421.0   405.0
# NZ_CP115646.1  GCF_024106315.1_ASM2410631v2_genomic  plasmid  2197.0  1453.0
# ...                                             ...      ...     ...     ...
# NZ_CP014366.1   GCF_003595385.1_ASM359538v1_genomic  plasmid   223.0    69.0
# NZ_CP014367.1   GCF_003595385.1_ASM359538v1_genomic  plasmid  1170.0   404.0
# NZ_CP098817.1  GCF_039640675.1_ASM3964067v1_genomic  plasmid  1872.0   601.0
# NZ_CP098818.1  GCF_039640675.1_ASM3964067v1_genomic  plasmid  1725.0   578.0
# NZ_CP098819.1  GCF_039640675.1_ASM3964067v1_genomic  plasmid  1068.0   291.0
#
#                  AAAG    AAAT    AACA    AACC    AACG    AACT  ...    TAAA  \
# SeqID                                                          ...
# CP077813.1      521.0   559.0   446.0   491.0   501.0   349.0  ...   468.0
# NZ_CP100133.1   635.0   635.0   838.0  1019.0  1727.0   809.0  ...   230.0
# NZ_CP100134.1   506.0   594.0   683.0   713.0  1188.0   599.0  ...   220.0
# NZ_CP100135.1   403.0   386.0   448.0   561.0   894.0   431.0  ...   142.0
# NZ_CP115646.1  1528.0  1804.0  1287.0   854.0   954.0  1121.0  ...  1584.0
# ...               ...     ...     ...     ...     ...     ...  ...     ...
# NZ_CP014366.1    62.0   113.0    55.0    27.0    20.0    42.0  ...   119.0
# NZ_CP014367.1   505.0   876.0   340.0   170.0   166.0   285.0  ...   896.0
# NZ_CP098817.1   783.0  1408.0   620.0   238.0   269.0   527.0  ...  1425.0
# NZ_CP098818.1   868.0  1258.0   615.0   207.0   200.0   452.0  ...  1321.0
# NZ_CP098819.1   443.0   741.0   307.0   132.0   124.0   245.0  ...   758.0
#
#                 TACA   TAGA   TATA    TCAA    TCCA    TCGA    TGAA   TGCA  \
# SeqID
# CP077813.1     202.0  117.0  123.0   418.0   426.0   211.0   558.0  209.0
# NZ_CP100133.1  453.0  335.0   86.0  1139.0  1158.0  1726.0  1134.0  700.0
# NZ_CP100134.1  348.0  255.0   85.0   832.0   879.0  1127.0   864.0  514.0
# NZ_CP100135.1  243.0  219.0   61.0   654.0   626.0   932.0   598.0  379.0
# NZ_CP115646.1  732.0  646.0  270.0  1812.0   745.0   405.0  1537.0  452.0
# ...              ...    ...    ...     ...     ...     ...     ...    ...
# NZ_CP014366.1   23.0   28.0   31.0    54.0    18.0    11.0    40.0   10.0
# NZ_CP014367.1  282.0  267.0  315.0   394.0   167.0    65.0   415.0   98.0
# NZ_CP098817.1  515.0  427.0  499.0   636.0   252.0    84.0   635.0  139.0
# NZ_CP098818.1  420.0  487.0  488.0   607.0   202.0    47.0   676.0   69.0
# NZ_CP098819.1  262.0  237.0  300.0   327.0   132.0    44.0   366.0   73.0
#
#                 TTAA
# SeqID
# CP077813.1     230.0
# NZ_CP100133.1  101.0
# NZ_CP100134.1   85.0
# NZ_CP100135.1   50.0
# NZ_CP115646.1  822.0
# ...              ...
# NZ_CP014366.1   56.0
# NZ_CP014367.1  373.0
# NZ_CP098817.1  595.0
# NZ_CP098818.1  536.0
# NZ_CP098819.1  337.0
#
# [42637 rows x 138 columns]

# %%
# convert to kmer frequencies
# ignore terrible variable naming conventions idk what i'm doing here
data_c = data[labels_to_keep]
data_p = data_c[labels_to_keep_p]
p4m_swap = p4m.copy()
p4m_swap['SeqID'] = p4m.index
p4m_swap['Index'] = data_p.index
p4m_swap = p4m_swap.set_index('Index')
p_kmers = p4m_swap.iloc[:,2:-1]
p_sums = p_kmers.sum(axis=1)
p_freqs = p_kmers.div(p_sums, axis=0)

c4m['Index'] = data_c.index
c4m_red = c4m.set_index('Index')[labels_to_keep_p]
c_kmers = c4m_red.iloc[:,2:]
c_sums = c_kmers.sum(axis=1)
c_freqs = c_kmers.div(c_sums, axis=0)

# compute differences
diffs = p_freqs.add(c_freqs * -1)
diffs
# Out:
#            AAAA      AAAC      AAAG      AAAT      AACA      AACC      AACG  \
# Index
# 0      0.004185  0.002337  0.001374  0.003131  0.001823  0.002016  0.001201
# 1      0.001183  0.001414  0.001334  0.000828  0.000410  0.001287  0.001862
# 2      0.002077  0.002613  0.001905  0.002082  0.001282  0.001436  0.001957
# 3      0.001590  0.001251  0.001828  0.001159  0.000261  0.001261  0.001277
# 6     -0.007263 -0.000025 -0.000632 -0.004878  0.000528 -0.000807  0.002573
# ...         ...       ...       ...       ...       ...       ...       ...
# 50871  0.040992  0.009388  0.004369  0.006818  0.002392  0.002875 -0.000398
# 50872  0.012793  0.002214  0.003168  0.002990 -0.002663  0.000508 -0.000671
# 50873  0.014920  0.000959  0.001572  0.004497  0.000808 -0.000730 -0.000520
# 50874  0.016174  0.001974  0.005805  0.004442  0.002329 -0.000882 -0.001552
# 50875  0.019812  0.000231  0.003454  0.005417  0.000359 -0.000275 -0.001123
#
#            AACT      AAGA      AAGC  ...      TAAA      TACA      TAGA  \
# Index                                ...
# 0      0.002020 -0.000110 -0.000266  ...  0.001848  0.000585  0.000022
# 1      0.001243  0.001043  0.001101  ...  0.000486  0.000511  0.000181
# 2      0.001617  0.001071  0.001933  ...  0.000978  0.000818  0.000390
# 3      0.001085  0.001328  0.001408  ...  0.000627  0.000438  0.000502
# 6     -0.000400  0.001311  0.000960  ... -0.008027 -0.001340 -0.000483
# ...         ...       ...       ...  ...       ...       ...       ...
# 50871  0.003008  0.003382 -0.000987  ...  0.010244 -0.003564  0.000303
# 50872  0.000085  0.002121 -0.000164  ...  0.005233 -0.000511  0.001200
# 50873  0.000541  0.000639 -0.001268  ...  0.003686  0.001467 -0.000256
# 50874  0.000043  0.004587 -0.001617  ...  0.004841  0.000431  0.002398
# 50875 -0.000547  0.000312 -0.001530  ...  0.004974  0.001404  0.000567
#
#            TATA      TCAA      TCCA      TCGA      TGAA      TGCA      TTAA
# Index
# 0      0.000668  0.001316  0.000606 -0.000164  0.002044  0.000038  0.001203
# 1      0.000143  0.002160  0.001215 -0.000766  0.000750  0.000177  0.000307
# 2      0.000348  0.002599  0.001918 -0.001140  0.001464  0.000467  0.000433
# 3      0.000271  0.002389  0.001076 -0.000984  0.000471  0.000098  0.000251
# 6     -0.001589  0.003062  0.000417  0.001412 -0.000054 -0.001719 -0.001950
# ...         ...       ...       ...       ...       ...       ...       ...
# 50871  0.001873  0.001431 -0.000739  0.001112 -0.003973 -0.001684  0.004866
# 50872  0.003582 -0.001308 -0.000334 -0.000009 -0.001452 -0.001266  0.000711
# 50873  0.003444 -0.001436 -0.000884 -0.000265 -0.003109 -0.000660  0.000193
# 50874  0.004492 -0.000480 -0.001480 -0.000979 -0.000383 -0.002063  0.000281
# 50875  0.005426 -0.001362 -0.000746 -0.000219 -0.001284 -0.000576  0.001639
#
# [42637 rows x 136 columns]

# %%
# convert to RMSD across all kmers
rmsd = diffs ** 2
rmsd = rmsd.sum(axis=1)
rmsd = rmsd / 136 # * 1/n
rmsd = rmsd ** 0.5
# mean + std of RMSD across all samples
print(rmsd.mean(), '+/-', rmsd.std())
# Out:
# 0.0022763465391264304 +/- 0.0012708710726392703

# %%
# add full kmer profiles or just RMSD
full = False
if full:
    data_ext = pd.concat([data_p, diffs], axis=1)
else:
    data_ext = data_p.copy()
    data_ext['RMSD'] = rmsd
data_ext
# Out:
#                                        Assembly_ID                 Taxonomy  \
# 0      GCA_023703895.1_ASM2370389v1_genomic.fna.gz    KLEBSIELLA PNEUMONIAE
# 1      GCF_024662395.1_ASM2466239v1_genomic.fna.gz      BURKHOLDERIA GLUMAE
# 2      GCF_024662395.1_ASM2466239v1_genomic.fna.gz      BURKHOLDERIA GLUMAE
# 3      GCF_024662395.1_ASM2466239v1_genomic.fna.gz      BURKHOLDERIA GLUMAE
# 6      GCF_024106315.1_ASM2410631v2_genomic.fna.gz  ACINETOBACTER BAUMANNII
# ...                                            ...                      ...
# 50871   GCF_003595385.1_ASM359538v1_genomic.fna.gz    STAPHYLOCOCCUS AUREUS
# 50872   GCF_003595385.1_ASM359538v1_genomic.fna.gz    STAPHYLOCOCCUS AUREUS
# 50873  GCF_039640675.1_ASM3964067v1_genomic.fna.gz   STAPHYLOCOCCUS CAPITIS
# 50874  GCF_039640675.1_ASM3964067v1_genomic.fna.gz   STAPHYLOCOCCUS CAPITIS
# 50875  GCF_039640675.1_ASM3964067v1_genomic.fna.gz   STAPHYLOCOCCUS CAPITIS
#
#                      Chromosome_ID     Plasmid_ID  Chr_len  Plasmid_len  \
# 0                       CP077812.1     CP077813.1  5167508        54288
# 1      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100133.1  6558951       189346
# 2      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100134.1  6558951       128913
# 3      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100135.1  6558951       104740
# 6                    NZ_CP115645.1  NZ_CP115646.1  3917468       104651
# ...                            ...            ...      ...          ...
# 50871                NZ_CP014365.1  NZ_CP014366.1  2904958         3125
# 50872                NZ_CP014365.1  NZ_CP014367.1  2904958        27068
# 50873                NZ_CP098816.1  NZ_CP098817.1  2443214        44138
# 50874                NZ_CP098816.1  NZ_CP098818.1  2443214        39504
# 50875                NZ_CP098816.1  NZ_CP098819.1  2443214        22579
#
#          Chr_GC  Plasmid_GC      RMSD
# 0      0.575169    0.527888  0.001915
# 1      0.683257    0.638836  0.002416
# 2      0.683257    0.614430  0.003242
# 3      0.683257    0.636500  0.002477
# 6      0.392244    0.425471  0.001895
# ...         ...         ...       ...
# 50871  0.327958    0.287360  0.004323
# 50872  0.327958    0.305231  0.001853
# 50873  0.330543    0.300580  0.001924
# 50874  0.330543    0.289464  0.002272
# 50875  0.330543    0.289473  0.002463
#
# [42637 rows x 9 columns]

# %%
# compute other pairwise features
data_ext['Len_ratio'] = data_ext['Chr_len'].div(data_ext['Plasmid_len'])
data_ext['GC_abs_diff'] = data_ext['Chr_GC'].add(data_ext['Plasmid_GC'] * -1).abs()
data_ext
# Out:
#                                        Assembly_ID                 Taxonomy  \
# 0      GCA_023703895.1_ASM2370389v1_genomic.fna.gz    KLEBSIELLA PNEUMONIAE
# 1      GCF_024662395.1_ASM2466239v1_genomic.fna.gz      BURKHOLDERIA GLUMAE
# 2      GCF_024662395.1_ASM2466239v1_genomic.fna.gz      BURKHOLDERIA GLUMAE
# 3      GCF_024662395.1_ASM2466239v1_genomic.fna.gz      BURKHOLDERIA GLUMAE
# 6      GCF_024106315.1_ASM2410631v2_genomic.fna.gz  ACINETOBACTER BAUMANNII
# ...                                            ...                      ...
# 50871   GCF_003595385.1_ASM359538v1_genomic.fna.gz    STAPHYLOCOCCUS AUREUS
# 50872   GCF_003595385.1_ASM359538v1_genomic.fna.gz    STAPHYLOCOCCUS AUREUS
# 50873  GCF_039640675.1_ASM3964067v1_genomic.fna.gz   STAPHYLOCOCCUS CAPITIS
# 50874  GCF_039640675.1_ASM3964067v1_genomic.fna.gz   STAPHYLOCOCCUS CAPITIS
# 50875  GCF_039640675.1_ASM3964067v1_genomic.fna.gz   STAPHYLOCOCCUS CAPITIS
#
#                      Chromosome_ID     Plasmid_ID  Chr_len  Plasmid_len  \
# 0                       CP077812.1     CP077813.1  5167508        54288
# 1      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100133.1  6558951       189346
# 2      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100134.1  6558951       128913
# 3      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100135.1  6558951       104740
# 6                    NZ_CP115645.1  NZ_CP115646.1  3917468       104651
# ...                            ...            ...      ...          ...
# 50871                NZ_CP014365.1  NZ_CP014366.1  2904958         3125
# 50872                NZ_CP014365.1  NZ_CP014367.1  2904958        27068
# 50873                NZ_CP098816.1  NZ_CP098817.1  2443214        44138
# 50874                NZ_CP098816.1  NZ_CP098818.1  2443214        39504
# 50875                NZ_CP098816.1  NZ_CP098819.1  2443214        22579
#
#          Chr_GC  Plasmid_GC      RMSD   Len_ratio  GC_abs_diff
# 0      0.575169    0.527888  0.001915   95.186929     0.047281
# 1      0.683257    0.638836  0.002416   34.640029     0.044421
# 2      0.683257    0.614430  0.003242   50.878895     0.068827
# 3      0.683257    0.636500  0.002477   62.621262     0.046757
# 6      0.392244    0.425471  0.001895   37.433641     0.033227
# ...         ...         ...       ...         ...          ...
# 50871  0.327958    0.287360  0.004323  929.586560     0.040598
# 50872  0.327958    0.305231  0.001853  107.320748     0.022727
# 50873  0.330543    0.300580  0.001924   55.353981     0.029963
# 50874  0.330543    0.289464  0.002272   61.847256     0.041079
# 50875  0.330543    0.289473  0.002463  108.207361     0.041071
#
# [42637 rows x 11 columns]

# %%
# fetch SRCCs; takes a few minutes due to large file size
data_ext['SRCC'] = 0.0

# first trim assembly IDs
assemblies_trimmed = data_ext['Assembly_ID'].str[:-7].values

fn = '/fs/nexus-projects/plasmids/plasmid_host_range_2024_summer_interns/expanded_dataset/correlation_table_v4.txt'
index = 0
populated = 0
with open(fn, 'r') as f:
    # save list of plasmids
    plasmid_list = f.readline().split()
    while True:
        if index < 6800: # found in practice the first 6800 lines aren't present in data_ext, so this makes things faster
            next(f)
            index += 1
            continue
        line = f.readline()
        if line is None or line == '':
            break
        assembly = line.split('\t', 1)[0]
        assembly = assembly[:-15]
        # check for containment; assume all assemblies found
        if assembly in assemblies_trimmed:
            rows_found = data_ext[data_ext['Assembly_ID'].str[:-7] == assembly]
            for i, plasmid in enumerate(rows_found['Plasmid_ID']):
                if plasmid not in plasmid_list:
                    # drop row if plasmid not found
                    data_ext.drop(rows_found.iloc[i].name, inplace=True)
                else:
                    # if both assembly and plasmid are found, split line further to extract plasmid
                    plasmid_idx = plasmid_list.index(plasmid)
                    # if idx=1, we need 3 splits: 1 for assembly ID, 2 for ID + idx 0, 3 for ID + idx 0-1
                    # idx+1 indexing works in last index edge case, -2 indexing doesn't
                    srcc = line.split('\t', plasmid_idx+2)[plasmid_idx+1]
                    # update dataframe
                    data_ext.loc[rows_found.iloc[i].name, 'SRCC'] = float(srcc)
                    populated += 1
        index += 1
        if index % 5000 == 0:
            print('iter', index)
print(populated, 'rows populated out of', len(data_ext))
data_ext
# Out:
# iter 10000
# iter 15000
# iter 20000
# iter 25000
# iter 30000
# iter 35000
# iter 40000
# 41684 rows populated out of 41684
#                                        Assembly_ID                 Taxonomy  \
# 0      GCA_023703895.1_ASM2370389v1_genomic.fna.gz    KLEBSIELLA PNEUMONIAE
# 1      GCF_024662395.1_ASM2466239v1_genomic.fna.gz      BURKHOLDERIA GLUMAE
# 2      GCF_024662395.1_ASM2466239v1_genomic.fna.gz      BURKHOLDERIA GLUMAE
# 3      GCF_024662395.1_ASM2466239v1_genomic.fna.gz      BURKHOLDERIA GLUMAE
# 6      GCF_024106315.1_ASM2410631v2_genomic.fna.gz  ACINETOBACTER BAUMANNII
# ...                                            ...                      ...
# 50871   GCF_003595385.1_ASM359538v1_genomic.fna.gz    STAPHYLOCOCCUS AUREUS
# 50872   GCF_003595385.1_ASM359538v1_genomic.fna.gz    STAPHYLOCOCCUS AUREUS
# 50873  GCF_039640675.1_ASM3964067v1_genomic.fna.gz   STAPHYLOCOCCUS CAPITIS
# 50874  GCF_039640675.1_ASM3964067v1_genomic.fna.gz   STAPHYLOCOCCUS CAPITIS
# 50875  GCF_039640675.1_ASM3964067v1_genomic.fna.gz   STAPHYLOCOCCUS CAPITIS
#
#                      Chromosome_ID     Plasmid_ID  Chr_len  Plasmid_len  \
# 0                       CP077812.1     CP077813.1  5167508        54288
# 1      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100133.1  6558951       189346
# 2      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100134.1  6558951       128913
# 3      NZ_CP100131.1,NZ_CP100132.1  NZ_CP100135.1  6558951       104740
# 6                    NZ_CP115645.1  NZ_CP115646.1  3917468       104651
# ...                            ...            ...      ...          ...
# 50871                NZ_CP014365.1  NZ_CP014366.1  2904958         3125
# 50872                NZ_CP014365.1  NZ_CP014367.1  2904958        27068
# 50873                NZ_CP098816.1  NZ_CP098817.1  2443214        44138
# 50874                NZ_CP098816.1  NZ_CP098818.1  2443214        39504
# 50875                NZ_CP098816.1  NZ_CP098819.1  2443214        22579
#
#          Chr_GC  Plasmid_GC      RMSD   Len_ratio  GC_abs_diff    SRCC
# 0      0.575169    0.527888  0.001915   95.186929     0.047281  0.9044
# 1      0.683257    0.638836  0.002416   34.640029     0.044421  0.9816
# 2      0.683257    0.614430  0.003242   50.878895     0.068827  0.9658
# 3      0.683257    0.636500  0.002477   62.621262     0.046757  0.9788
# 6      0.392244    0.425471  0.001895   37.433641     0.033227  0.8831
# ...         ...         ...       ...         ...          ...     ...
# 50871  0.327958    0.287360  0.004323  929.586560     0.040598  0.9132
# 50872  0.327958    0.305231  0.001853  107.320748     0.022727  0.9643
# 50873  0.330543    0.300580  0.001924   55.353981     0.029963  0.9836
# 50874  0.330543    0.289464  0.002272   61.847256     0.041079  0.9706
# 50875  0.330543    0.289473  0.002463  108.207361     0.041071  0.9768
#
# [41684 rows x 12 columns]
